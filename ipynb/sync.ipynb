# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab import auth
auth.authenticate_user() # GCPアカウントでログイン

import os
import re

# Drive のベースディレクトリと GCS の同期先
BASE_DIR = "/content/drive/MyDrive/R-NaD-PokemonTCGP_experiments"
DEST_BASE = "gs://r-nad-pokemontcgp-checkpoints/R-NaD-PokemonTCGP_experiments"

# 1. mlflow のデータは全て同期 (mlruns フォルダを同期)
print("Syncing all mlflow data...")
if os.path.exists(f"{BASE_DIR}/mlruns"):
    print("MlFlow directory found.")
    # !gsutil -m rsync -r {BASE_DIR}/mlruns {DEST_BASE}/mlruns

# 2. チェックポイントはcheckpoints直下の.pklのみ双方向で同期
print("Syncing checkpoints bidirectionally...")
CKPT_DIR = f"{BASE_DIR}/checkpoints"
GCS_CKPT_DIR = f"{DEST_BASE}/checkpoints"

import os
import subprocess

os.makedirs(CKPT_DIR, exist_ok=True)

# Drive -> GCS (無いファイルのみコピー)
drive_pkls = [f for f in os.listdir(CKPT_DIR) if f.endswith(".pkl") and os.path.isfile(os.path.join(CKPT_DIR, f))]
if drive_pkls:
    print(f"Copying {len(drive_pkls)} .pkl files from Drive to GCS...")
    # !gsutil -m cp -n {CKPT_DIR}/*.pkl {GCS_CKPT_DIR}/
else:
    print("No .pkl files found in Drive to copy to GCS.")

# GCS -> Drive (無いファイルのみコピー)
gcs_ls = subprocess.run(["gsutil", "ls", f"{GCS_CKPT_DIR}/*.pkl"], capture_output=True, text=True)
if gcs_ls.returncode == 0 and gcs_ls.stdout.strip():
    print("Copying .pkl files from GCS to Drive...")
    # !gsutil -m cp -n {GCS_CKPT_DIR}/*.pkl {CKPT_DIR}/
else:
    print("No .pkl files found in GCS to copy to Drive.")
